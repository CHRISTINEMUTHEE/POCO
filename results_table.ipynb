# %%
import pandas as pd
import json
path = "results/ShapeNet_None_FKAConv_InterpAttentionKHeadsNet_None/inference_timing.json"
# Load the JSON file
with open(path, 'r') as f:
    data = json.load(f)

# Extract the timing data into a DataFrame
timing_data = pd.DataFrame(data['timing_data'])
timing_data

# # Export to CSV or Excel
timing_data.to_csv('results/ShapeNet_None_FKAConv_InterpAttentionKHeadsNet_None/inference_timing.csv', index=False)
# timing_data.to_excel('results/ShapeNet_None_FKAConv_InterpAttentionKHeadsNet_None/inference_timing.xlsx', index=False)

# print("Export completed successfully!")
# Out:
#     sample_index  shape_id  sample_time  inference_time  mesh_generation_time  \
# 0              1         0     4.292289        1.505996              2.781982
# 1              2         1     2.352659        0.061399              2.287973
# 2              3         2     2.548161        0.059929              2.484552
# 3              4         3     2.789719        0.059597              2.726251
# 4              5         4     3.897806        0.058663              3.834155
# ..           ...       ...          ...             ...                   ...
# 95            96        95     3.067775        0.059501              3.004194
# 96            97        96     4.392445        0.060328              4.326608
# 97            98        97     2.412433        0.058717              2.350501
# 98            99        98     3.017677        0.060346              2.953243
# 99           100        99     3.253700        0.059345              3.190147
#
# ...
